# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../results/test/testing/data/testing_episode_summary_5019.csv')
df.head()
# Out:
#    epi    t     reward      normo  hypo  sev_hypo      hyper      lgbi  \
# 0    1  288  238.57547  26.388889   0.0       0.0  46.180556  0.000000
# 1    2  288  264.40192  59.027778   0.0       0.0  34.722222  0.316164
# 2    3  288  275.60486  76.041667   0.0       0.0  23.958333  1.913147
# 3    4  288  262.34882  44.444444   0.0       0.0  54.861111  1.149471
# 4    5  288  280.01233  90.277778   0.0       0.0   9.722222  1.498636
#
#         hgbi         ri  sev_hyper  aBGP_rmse  cBGP_rmse
# 0  17.152369  17.152369  27.430556          0          0
# 1   8.872870   9.189034   6.250000          0          0
# 2   4.997820   6.910966   0.000000          0          0
# 3   9.038995  10.188466   0.694444          0          0
# 4   2.948219   4.446855   0.000000          0          0

# %%
plt.plot(df['epi'], df['reward'])
plt.show()

# %%
plt.plot(df['epi'], df['normo'])
plt.show()

# %%
plt.plot(df['epi'], df['hypo'])
plt.show()

# %%
plt.plot(df['epi'], df['sev_hypo'])
plt.show()

# %%
df = pd.read_csv('../../results/test/training/data/training_episode_summary_20.csv')
df.head()
# Out:
#    epi   t     reward      normo       hypo   sev_hypo  hyper       lgbi  \
# 0    0  36  17.329124  63.888889  25.000000  11.111111    0.0  14.382867
# 1    1  31  12.669638  74.193548   6.451613  19.354839    0.0  13.153530
# 2    2  29  11.687815  82.758621  10.344828   6.896552    0.0  11.831455
# 3    3  30  12.438972  76.666667  10.000000  13.333333    0.0  14.466740
# 4    4  34  16.129564  79.411765   5.882353  14.705882    0.0  13.959268
#
#        hgbi         ri  sev_hyper  aBGP_rmse  cBGP_rmse
# 0  2.569966  16.952833        0.0          0          0
# 1  4.613425  17.766956        0.0          0          0
# 2  2.178138  14.009593        0.0          0          0
# 3  1.832076  16.298815        0.0          0          0
# 4  2.619882  16.579150        0.0          0          0

# %%
plt.plot(df['epi'], df['reward'])
plt.show()

# %%
plt.plot(df['epi'], df['normo'])
plt.show()

# %%
plt.plot(df['epi'], df['hypo'])
plt.show()

# %%
plt.plot(df['epi'], df['sev_hypo'])
plt.show()

# %%
plt.plot(df['epi'], df['sev_hyper'])
plt.show()
